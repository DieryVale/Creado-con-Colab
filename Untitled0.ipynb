# %% [markdown]
# <a href="https://colab.research.google.com/github/DieryVale/Creado-con-Colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# este es el primerNootebook en python desde Colab. El objetivo del dia de hoy...
# para instalar,!pip install pandas![slide_16.jpg](data:image/jpeg;base64,...)

# %%
#!
# import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
import seaborn as sns
import plotly.express as px

drive.mount('/content/drive')
all_names = ('class','Alcohol','Malicacid','Ash','Alcalinity_of_ash','Magnesium','Total_phenols','Flavanoids','Nonflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','0D280_0D315_of_diluted_wines', 'Proline')
url_name = "/content/drive/MyDrive/wine.data"
# making data frame from csv file
data = pd.read_csv(url_name, names = all_names)
data.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malicacid                     178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity_of_ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total_phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid_phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
# ...

# %% [markdown]
# realizar estadística descriptiva

# %%
#data.head(100)
data.describe()
some_names = ['Alcohol','Malicacid','Ash','Alcalinity_of_ash']
data_some_cols = data[some_names]
data_some_cols.describe()
# Out:
#           Alcohol   Malicacid         Ash  Alcalinity_of_ash
# count  178.000000  178.000000  178.000000         178.000000
# mean    13.000618    2.336348    2.366517          19.494944
# std      0.811827    1.117146    0.274344           3.339564
# min     11.030000    0.740000    1.360000          10.600000
# 25%     12.362500    1.602500    2.210000          17.200000
# 50%     13.050000    1.865000    2.360000          19.500000
# 75%     13.677500    3.082500    2.557500          21.500000
# max     14.830000    5.800000    3.230000          30.000000

# %%
histogram = data_some_cols.plot.hist(bins = 8, edgecolor='black')
plt.show()

# %%
sns.boxplot(data = data, x = 'Alcohol' )
# Out:
# <Axes: xlabel='Alcohol'>

# %% [markdown]
# Crear un diagrama de dispersión

# %%
sns.scatterplot(data = data, x = 'Alcohol', y = 'Malicacid' )
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malicacid'>

# %% [markdown]
# Vamos a crear una matriz de scatterplots

# %%
fig = px.scatter_matrix(data, dimensions = some_names, color = 'class')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Calcular coedicientes de coorelacion
#
# ![image.png]()

# %%
corr_mat = data.corr()
sns.heatmap(corr_mat, annot = True, fmt = '.2f', cmap = 'coolwarm',xticklabels = corr_mat.columns, yticklabels = corr_mat.columns)
# Out:
# <Axes: >
